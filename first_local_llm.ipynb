# %% [markdown]
# # 环境介绍
# 本示例运行在windows
#
# # 本示例概要
# 本示例主要是带领大家如何在本地端建置属于自己的LLM，一般在企业为了省钱与治安考量都会考虑才用本地端进行部署LLM，那我们接着来实作吧。
#
#
# # 安装说明
#
# 1️⃣ 安装ollama
#
# 1.   进入网址https://ollama.com/download/windows 进行下载，我选择windows。跟着下载安装步骤执行，会安装自C槽哦。
# 2.   接下来用管理者的身份开启windows里的命令提示字元，来确认是否安装完成。打上ollama，出现指令说明就是安装完成。
#
# 2️⃣ 安装mistral
#
# 1.   接着上述操作，在命令提示字元打上ollama run mistral
#
# 3️⃣ 在Anaconda上安装相关套件
# 1.   用管理者的身份开启Anaconda Prompt 安装ollama套件，执行pip install ollama
# 2.   接着安装streamlit套件，执行pip install streamlit
#
#
# 4️⃣ 范例代码
#
#
# 1.   首先我们先把页面的代码进行撰写，并透过streamlit来查看页面

# %%
import streamlit as st
import ollama

def main():
    st.title("我的第一個自然語言對話程式")

    #設置用戶輸入框
    user_input = st.text_area("您想問什麼？","")

    #當使用者按下送出按鈕後的處理
    if st.button("送出"):
        if user_input:
            #使用ollama模型，進行對話
            response = ollama.chat(model='mistral',messages=[{'role': 'user', 'content': user_input}])

            #顯示回答
            st.text("回答：")
            st.write(response['message']['content'])
        else:
            st.warning("請輸入問題！")

if __name__ == "__main__":
    main()

# %% [markdown]
# 2.   打开Anaconda Prompt切换到上面python的脚本位置，执行cd python的脚本位置指令。
#
# > cd C:\Users\joyce
#
# 3.   再来继续在Anaconda Prompt执行python -m streamlit run 您的程序名称。这里要注意streamlit版本，执行语法可能会有差异。你的第一个本地端自然语言对话程式就完成。
#
# > python -m streamlit run first_local_llm.py
#
#
#
# ![fc37ef9062ecfe8aeebe6f980b97b45.png](data:image/png;base64,...)
